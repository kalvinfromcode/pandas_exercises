# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', sep=',')

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.head()
wine.drop(wine.columns[[0, 3, 6, 8, 10, 12, 13]], axis=1, inplace=True)

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium' ,'flavanoids', 'proanthocyanins', 'hue']

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.loc[0:3, 'alcohol'] = np.nan

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[[2, 3], 'magnesium'] = np.nan

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine['alcohol'].fillna(10, inplace=True)
wine['magnesium'].fillna(100, inplace=True)

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
random_indices = np.random.randint(10, size=10)
random_indices
# Out:
# array([8, 6, 9, 1, 4, 0, 9, 5, 7, 3])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.iloc[random_indices, :] = np.nan

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum().sum()
# Out:
# 63

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine.dropna(inplace=True)

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine['alcohol'][~wine['alcohol'].isnull()]

# alt
wine.alcohol[wine.alcohol.notnull()]
# Out:
# 2      10.00
# 10     14.12
# 11     13.75
# 12     14.75
# 13     14.38
# 14     13.63
# 15     14.30
# 16     13.83
# 17     14.19
# 18     13.64
# 19     14.06
# 20     12.93
# 21     13.71
# 22     12.85
# 23     13.50
# 24     13.05
# 25     13.39
# 26     13.30
# 27     13.87
# 28     14.02
# 29     13.73
# 30     13.58
# 31     13.68
# 32     13.76
# 33     13.51
# 34     13.48
# 35     13.28
# 36     13.05
# 37     13.07
# 38     14.22
#        ...
# 147    13.32
# 148    13.08
# 149    13.50
# 150    12.79
# 151    13.11
# 152    13.23
# 153    12.58
# 154    13.17
# 155    13.84
# 156    12.45
# 157    14.34
# 158    13.48
# 159    12.36
# 160    13.69
# 161    12.85
# 162    12.96
# 163    13.78
# 164    13.73
# 165    13.45
# 166    12.82
# 167    13.58
# 168    13.40
# 169    12.20
# 170    12.77
# 171    14.16
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 168, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine.reset_index()
# Out:
#      index  alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        2    10.00        1.95               16.8      100.0        3.49
# 1       10    14.12        1.48               16.8       95.0        2.43
# 2       11    13.75        1.73               16.0       89.0        2.76
# 3       12    14.75        1.73               11.4       91.0        3.69
# 4       13    14.38        1.87               12.0      102.0        3.64
# 5       14    13.63        1.81               17.2      112.0        2.91
# 6       15    14.30        1.92               20.0      120.0        3.14
# 7       16    13.83        1.57               20.0      115.0        3.40
# 8       17    14.19        1.59               16.5      108.0        3.93
# 9       18    13.64        3.10               15.2      116.0        3.03
# 10      19    14.06        1.63               16.0      126.0        3.17
# 11      20    12.93        3.80               18.6      102.0        2.41
# 12      21    13.71        1.86               16.6      101.0        2.88
# 13      22    12.85        1.60               17.8       95.0        2.37
# 14      23    13.50        1.81               20.0       96.0        2.61
# 15      24    13.05        2.05               25.0      124.0        2.68
# 16      25    13.39        1.77               16.1       93.0        2.94
# 17      26    13.30        1.72               17.0       94.0        2.19
# 18      27    13.87        1.90               19.4      107.0        2.97
# 19      28    14.02        1.68               16.0       96.0        2.33
# 20      29    13.73        1.50               22.5      101.0        3.25
# 21      30    13.58        1.66               19.1      106.0        3.19
# 22      31    13.68        1.83               17.2      104.0        2.69
# 23      32    13.76        1.53               19.5      132.0        2.74
# 24      33    13.51        1.80               19.0      110.0        2.53
# 25      34    13.48        1.81               20.5      100.0        2.98
# 26      35    13.28        1.64               15.5      110.0        2.68
# 27      36    13.05        1.65               18.0       98.0        2.43
# 28      37    13.07        1.50               15.5       98.0        2.64
# 29      38    14.22        3.99               13.2      128.0        3.04
# ..     ...      ...         ...                ...        ...         ...
# 138    147    13.32        3.24               21.5       92.0        0.76
# 139    148    13.08        3.90               21.5      113.0        1.39
# 140    149    13.50        3.12               24.0      123.0        1.57
# 141    150    12.79        2.67               22.0      112.0        1.36
# 142    151    13.11        1.90               25.5      116.0        1.28
# 143    152    13.23        3.30               18.5       98.0        0.83
# 144    153    12.58        1.29               20.0      103.0        0.58
# 145    154    13.17        5.19               22.0       93.0        0.63
# 146    155    13.84        4.12               19.5       89.0        0.83
# 147    156    12.45        3.03               27.0       97.0        0.58
# 148    157    14.34        1.68               25.0       98.0        1.31
# 149    158    13.48        1.67               22.5       89.0        1.10
# 150    159    12.36        3.83               21.0       88.0        0.92
# 151    160    13.69        3.26               20.0      107.0        0.56
# 152    161    12.85        3.27               22.0      106.0        0.60
# 153    162    12.96        3.45               18.5      106.0        0.70
# 154    163    13.78        2.76               22.0       90.0        0.68
# 155    164    13.73        4.36               22.5       88.0        0.47
# 156    165    13.45        3.70               23.0      111.0        0.92
# 157    166    12.82        3.37               19.5       88.0        0.66
# 158    167    13.58        2.58               24.5      105.0        0.84
# 159    168    13.40        4.60               25.0      112.0        0.96
# 160    169    12.20        3.03               19.0       96.0        0.49
# 161    170    12.77        2.39               19.5       86.0        0.51
# 162    171    14.16        2.51               20.0       91.0        0.70
# 163    172    13.71        5.65               20.5       95.0        0.61
# 164    173    13.40        3.91               23.0      102.0        0.75
# 165    174    13.27        4.28               20.0      120.0        0.69
# 166    175    13.17        2.59               20.0      120.0        0.68
# 167    176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               2.18  0.86
# 1               1.57  1.17
# 2               1.81  1.15
# 3               2.81  1.25
# 4               2.96  1.20
# 5               1.46  1.28
# 6               1.97  1.07
# 7               1.72  1.13
# 8               1.86  1.23
# 9               1.66  0.96
# 10              2.10  1.09
# 11              1.98  1.03
# 12              1.69  1.11
# 13              1.46  1.09
# 14              1.66  1.12
# 15              1.92  1.13
# 16              1.45  0.92
# 17              1.35  1.02
# 18              1.76  1.25
# 19              1.98  1.04
# 20              2.38  1.19
# 21              1.95  1.09
# 22              1.97  1.23
# 23              1.35  1.25
# 24              1.54  1.10
# 25              1.86  1.04
# 26              1.36  1.09
# 27              1.44  1.12
# 28              1.37  1.18
# 29              2.08  0.89
# ..               ...   ...
# 138             1.25  0.55
# 139             1.14  0.57
# 140             1.25  0.59
# 141             1.26  0.48
# 142             1.56  0.61
# 143             1.87  0.56
# 144             1.40  0.58
# 145             1.55  0.60
# 146             1.56  0.57
# 147             1.14  0.67
# 148             2.70  0.57
# 149             2.29  0.57
# 150             1.04  0.56
# 151             0.80  0.96
# 152             0.96  0.87
# 153             0.94  0.68
# 154             1.03  0.70
# 155             1.15  0.78
# 156             1.46  0.85
# 157             0.97  0.72
# 158             1.54  0.74
# 159             1.11  0.67
# 160             0.73  0.66
# 161             0.64  0.57
# 162             1.24  0.62
# 163             1.06  0.64
# 164             1.41  0.70
# 165             1.35  0.59
# 166             1.46  0.60
# 167             1.35  0.61
#
# [168 rows x 8 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.
